# %% [markdown]
# <a href="https://colab.research.google.com/github/FloraAmato/Lezioni/blob/main/Copia_di_PrimaLezione.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #Primo Programma
# ## Descrizione
# ### Informazioni
# Questo è il mio primo programma Python in Google Colab condiviso

# %%
a="Flora"
a
# Out:
# 'Flora'

# %%
a=16
a
# Out:
# 16

# %% [markdown]
# #Secondo Programma
#
# Questo strumento è interessante

# %% [markdown]
# # Terzo Programma
# # **Nuova sezione**
# *ciao*
#
#
#
# ```
# # Questo è formattato come codice
# ```
#
# coll ipert[testo del link](https://)
#
#
# ![WhatsApp Image 2021-04-06 at 19.23.57.jpeg](data:image/jpeg;base64,...)

# %%
A=1555
A
# Out:
# 1555

# %%
gae="Gaetano"
gae
# Out:
# 'Gaetano'

# %%
hello="Ciao Gaetano"
hello
# Out:
# 'Ciao Gaetano'
